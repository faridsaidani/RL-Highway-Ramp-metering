# %%
import pandas as pd

# %%
df = pd.read_csv('results_ql_checkpoints.csv')

# %%
df
# Out:
#                                    Model  Average Reward
# 0   q_learning_checkpoint_1000_17928.pkl     -398.829285
# 1   q_learning_checkpoint_1000_17929.pkl     -542.644389
# 2   q_learning_checkpoint_1000_17930.pkl     -558.506861
# 3   q_learning_checkpoint_1000_17931.pkl     -296.566486
# 4   q_learning_checkpoint_1000_17932.pkl     -407.238168
# ..                                   ...             ...
# 95   q_learning_checkpoint_950_17928.pkl     -668.365292
# 96   q_learning_checkpoint_950_17929.pkl     -270.221581
# 97   q_learning_checkpoint_950_17930.pkl     -406.984886
# 98   q_learning_checkpoint_950_17931.pkl     -362.461319
# 99   q_learning_checkpoint_950_17932.pkl     -405.739029
#
# [100 rows x 2 columns]

# %%
df.sort_values(by='Average Reward', ascending=False).head(10)
# Out:
#                                   Model  Average Reward
# 26  q_learning_checkpoint_300_17929.pkl     -218.191159
# 7   q_learning_checkpoint_100_17930.pkl     -245.044885
# 44  q_learning_checkpoint_450_17932.pkl     -262.409484
# 71  q_learning_checkpoint_700_17929.pkl     -266.307040
# 91  q_learning_checkpoint_900_17929.pkl     -267.245063
# 96  q_learning_checkpoint_950_17929.pkl     -270.221581
# 85  q_learning_checkpoint_850_17928.pkl     -271.583186
# 83  q_learning_checkpoint_800_17931.pkl     -272.639956
# 6   q_learning_checkpoint_100_17929.pkl     -291.040275
# 69  q_learning_checkpoint_650_17932.pkl     -295.585761
